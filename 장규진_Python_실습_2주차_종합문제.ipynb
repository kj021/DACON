# %% [markdown]
# <a href="https://colab.research.google.com/github/kj021/DACON/blob/main/%EC%9E%A5%EA%B7%9C%EC%A7%84_Python_%EC%8B%A4%EC%8A%B5_2%EC%A3%BC%EC%B0%A8_%EC%A2%85%ED%95%A9%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **2주차 종합문제**
#
#
# 이 자료는 <2022 OUTTA AI 부트캠프> Python 기초 교육 실습을 위해 작성되었습니다. 총 2문제로 구성되어 있습니다.
#
# 아래 셀은 수정하지 마시고, 반드시 문제를 **풀기 전에 실행**시켜 주시기 바랍니다.
#
# 실행 과정에서 Google 계정 로그인이 필요합니다. 반드시 **Classroom 에 등록한 계정과 동일한 계정으로 로그인** 해 주시기 바랍니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !git clone https://github.com/frogyunmax/OUTTA
# %cd OUTTA

# %% [markdown]
# ### (Numpy) Problem 1. *Handling of Numpy Arrays*
#
#
# *Problem Description*
#
# 이 문제에서는 'Python 기초 교육' 중 3단원에서 학습한 Numpy 의 여러 기능들을 이용해, Numpy array 를 자유자재로 다루어 보는 연습을 할 것이다. 아래 코드를 실행하고, 물음에 답하시오.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img = mpimg.imread('cat.png')

# %% [markdown]
# **(1)** `img`는 Numpy array type의 변수이다. `img`의 shape를 출력하시오.
#
# * *Hint* : use `np.shape`

# %% [markdown]
# **(2)** `img` 는 3차원 Numpy array 이다. (1)에서 구한 shape 를 (A, B, C) 라고 할 때, `np.transpose` 를 이용하여 shape 가 (C, A, B) 인 새로운 3차원 Numpy array `img_2` 를 생성하여라.

# %% [markdown]
# **(3)**  (2)에서 만든 `img_2` 변수의 shape를 출력하여라.

# %% [markdown]
# **(4)** `img_2` 에서 아래 설명에 해당하는 부분을 Slicing 해 2차원 Numpy array 인 `data` 변수를 생성하시오.
#
# - 첫 번째 차원 : index 2
#
# - 두 번째 차원 : index 100 ~ 299
#
# - 세 번째 차원 : index 70 ~ 269
#
# 또한, `data` 변수의 shape를 출력해, 그 값이 (200, 200) 인지 확인하시오.

# %% [markdown]
# **(5)** `data` 는 Float Number 로 이루어진 2차원 Numpy array 이다. `data` 내 원소의 최댓값과 최솟값을 구하시오.
# * *Restriction*  : 모든 풀이 과정에서 `for` 문은 사용할 수 없다. Numpy 에서 제공하는 함수만을 사용하시오.

# %% [markdown]
# **(6)** (5)에서 구한 최댓값과 최솟값을 각각 A, B 라는 변수에 저장하시오.

# %% [markdown]
# **(7)** (6)에서 구한 값 $A, \; B$ 를 이용해, 아래 연산을 수행하는 함수 f(x) 를 정의하시오.
#
# $f(x) = \frac{x - A}{B-A}$

# %%
def f(x):
    return

# %% [markdown]
# **(8)** `data`의 각 원소의 값을 $x$ 라 하자. 모든 원소의 값이 $f(x)$ 로 바뀐 2차원 numpy array 를 `data_f` 라고 하자. `data_f` 를 생성하고 출력하시오.

# %% [markdown]
# **(9)** `data_f` 에 대해, `np.max`와 `np.min` 을 이용해, `data_f` 내 원소의 최댓값과 최솟값을 구하시오.
# * *Restriction*  : 모든 풀이 과정에서 `for` 문은 사용할 수 없다. Numpy 에서 제공하는 함수만을 사용하시오.

# %% [markdown]
# **(10)** `data_f` 는 2차원 numpy array 이다. 각 행에 대해, 행에 있는 원소 200개의 평균을 행의 값으로 대체한 행렬 `data_f_row`를 생성하시오 (즉, 열의 개수를 200개에서 1개로 축소하시오).
#
# 이 때, 새로운 행렬의 차원은 **1차원**이어야 한다. `data_f_row`의 shape 값이 (200,) 이 되는지 확인하시오.
#
# 예를 들어,
#
#
# \begin{pmatrix}
# 1&2&3\\
# 3&4&5\\
# 4&5&6
# \end{pmatrix}
# 의 행렬을
#
# \begin{pmatrix}
# 2.0\\
# 4.0\\
# 5.0
# \end{pmatrix}
#
#  으로 변환하시오.
#
#
# * *Restriction*  : 모든 풀이 과정에서 `for` 문은 사용할 수 없다. Numpy 에서 제공하는 함수만을 사용하시오.

# %% [markdown]
# **(11)** 이번에는, 각 열에 대해 열에 있는 원소 200개의 평균을 열의 값으로 대체한 행렬 `data_f_col`를 생성하시오 (즉, 행의 개수를 200개에서 1개로 축소하시오).
#
# 이 때, 새로운 행렬의 차원도 **2차원**으로 유지되어야 한다. `data_f_avg`의 shape 값이 (1, 200) 이 되는지 확인하시오.
#
# 예를 들어,
#
#
# \begin{pmatrix}
# 1&2&3\\
# 3&4&5\\
# 4&5&6
# \end{pmatrix}
# 의 행렬을
#
# \begin{pmatrix}
# 2.66667&3.66667&4.66667\\
# \end{pmatrix}
#
#  으로 변환하시오.
#
#
# * *Restriction*  : 모든 풀이 과정에서 `for` 문은 사용할 수 없다. Numpy 에서 제공하는 함수만을 사용하시오.

# %% [markdown]
# **(12)** (11)에서 구한 `data_f_col`에 대해, 최댓값을 가지는 **열의 번호** 를 출력하시오. 단, 열의 번호는 0부터 시작하며, 반드시 숫자 1개만 출력되어야 한다. 예를 들어 [2] 가 아니라 2 가 출력되어야 한다.
#
# * *Hint* : use `np.argmax` and set `axis = 1`. use `np.item()`.

# %% [markdown]
# **(13)** 이번에는, `data_f_col`의 각 원소가 0.5 미만인지, 이상인지 판별해 보자. 각 원소에 대해, 원소의 값이 0.5 미만이면 `False`가, 0.5 이상이면 `True`가 해당 원소의 값으로 대체왼 행렬 `data_f_bool` 을 생성하고 출력하시오.
#
# 예를 들어,
#
# \begin{pmatrix}
# 0.266667&0.366667&0.566667\\
# \end{pmatrix}
# 의 행렬을
#
# \begin{pmatrix}
# False&False&True\\
# \end{pmatrix}
#
# 로 변환하시오.
#
#
#
# * *Restriction*  : 모든 풀이 과정에서 `for` 문은 사용할 수 없다.

# %% [markdown]
# **(14)** (13)의 결과를 이용해, `data_f_col` 원소 중 0.5이상인 원소의 개수를 출력하시오.
#
# * *Hint* : use `np.sum` and `axis = ?` and `np.item()`. `True`는 1과 동일하다.

# %% [markdown]
# ### (Class) Problem 2. *Perform Unknown Operations!*

# %% [markdown]
# *Problem Description*

# %% [markdown]
# 이 문제에서는, Numpy array 2개를 이용한 '미지의 연산' 을 수행하는 Python Class 를 선언하고 '미지의 연산' 을 직접 수행해 볼 것이다. 이 문제를 풀기 위해서는 Numpy 와 Class 에 대한 개념이 모두 필요하므로, 충분히 개념을 복습한 후 풀어보도록 하자.

# %% [markdown]
# '미지의 연산' 을 ◎ 라고 표기하자. 그 연산 방식은 아래와 같다. 예를 들어, 두 행렬 A와 B를 생각해 보자.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A ◎ B 의 값은 3 X 3 행렬로, 그 연산 방식은 아래 그림과 같다. 총 9단계로 이루어져 있다.
#
# 행렬 A의 왼쪽 상단부터, B를 포개고 원소별 곱을 계산한 후 이를 모두 더한 값을 계산한다. 이후, 행렬 B를 오른쪽으로 1칸씩 이동시키고, 더 이상 오른쪽으로 이동할 수 없다면 한 줄 아래의 맨 왼쪽위치로 이동시킨 뒤 동일한 작업을 반복한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위 연산에 필요한 행렬을 생성하고, 연산을 수행하는 class `operation` 을 정의해 볼 것이다.

# %% [markdown]
# **(1)** class 의 `__init__(self)` 함수를 정의하여라. class variable 은 4개이며, 각각의 type과 초기화 방식은 아래에 나타내었다.
# - `self.arrayA` : 행렬 A를 나타내는 2차원 Numpy array. `np.zeros`를 이용해, (1, 1) 크기로 초기화하여라.
# - `self.arrayB` : 행렬 B를 나타내는 2차원 Numpy array. `np.zeros`를 이용해, (1, 1) 크기로 초기화하여라.
# - `self.arrayC` : A ◎ B 를 나타내는 2차원 Numpy array. `np.zeros`를 이용해, (1, 1) 크기로 초기화하여라.
# - `self.sum_value` : `self.arrayC` 모든 원소의 합을 나타내는 int 형 변수. 0으로 초기화하여라.

# %% [markdown]
# **(2)** 위 연산에 필요한 행렬 A, B 를 생성하는 함수 `make_array` 를 정의하자. 함수의 parameters 와 return value 는 아래 나타내었다.
#
# *parameters*
# - `width` : 생성할 행렬의 행의 수, int 형 변수
# - `length` : 생성할 행렬의 열의 수, int 형 변수
# - `param` : 문자형 변수이다. 'A' 또는 'a' 가 입력되면 행렬 A를 생성하고, 'B' 또는 'b' 가 입력되면 행렬 B를 생성한다.
#
# *function operation*
# - parameter 로 입력받은 width, length 에 대해 크기가 (width, length)인 2차원 Numpy array 를 생성한다.
# - 이 때, 생성된 array 의 각 원소는 0 이상 9 이하의 정수 중 임의의 값을 가지게 한다. (Hint : use `np.random.randint`)
# - `param` 의 값이 'A' 또는 'a' 인 경우 생성한 array를 `self.arrayA` 에 저장한다. 반대로 'B' 또는 'b'인 경우 생성한 array를 `self.arrayB` 에 저장한다. 이외 값이 입력된 경우, "Cannot make array!" 를 출력하고 생성한 배열을 저장하지 않는다.
#
# *return value*
# - `param`의 값이 'A', 'a', 'B', 'b' 인 경우 생성한 (width, length) 크기의 2차원 Numpy array를 반환한다.
# - 이외 경우, `None` 값을 반환한다.

# %% [markdown]
# **(3)** A ◎ B를 수행하는 함수 `calculate` 를 정의하자.
#
# *parameters*
# - 별도의 parameter는 존재하지 않는다. `make_array` 함수를 통해 update 한 `self.arrayA` 값과 `self.arrayB` 값을 이용하자.
#
# *function operation*
# - `self.sum_value` 를 0으로 초기화한다.
# - `self.arrayA` 가 행렬 A, `self.arrayB` 가 행렬 B라 하고 A ◎ B 를 수행한다.
# - A ◎ B 를 수행한 결과 (2차원 Numpy array)를 `self.arrayC` 에 저장한다.
# - `self.arrayC` 내의 모든 원소의 합을 구해 `self.sum_value` 에 저장한다.
#
#
# *return value*
# - Tuple 형태로, (`self.arrayC`, `self.sum_value`) 값을 반환한다.
#
# *Hint*
# - A ◎ B 를 수행하기 위해, 4중 for 문을 사용할 수 있다.
# - 행렬의 크기가 맞지 않아서 (예를 들어, B의 행의 수가 A의 행의 수보다 많은 경우) 연산이 이루어질 수 없는 경우는 고려하지 않는다.

# %%
class operation:
    def __init__(self):
        
        
    def make_array(self, width, length, param):
        
        
        
        return 
    
    
    def calculate(self):
        
        
        return (self.arrayC, self.sum_value)

# %% [markdown]
# **(4)** operation Class 에 대한 인스턴스 객체 `op`를 생성하시오.

# %% [markdown]
# **(5)** `make_array` 함수를 이용해 행렬 A와 B를 생성하시오.
# - A의 Size는 (7, 8)이 되도록 설정하여라.
# - B의 Size는 (3, 2)이 되도록 설정하여라.

# %% [markdown]
# **(6)** (5)에서 생성한 A, B 를 출력하시오.

# %% [markdown]
# **(7)** `calculate` 함수를 이용해 (5)에서 생성한 행렬 A, B에 대해 A ◎ B 를 계산하고 그 값을 C에 저장하시오. 그리고 C의 값을 출력하시오.

# %% [markdown]
# **(8)** C의 shape 와 C의 모든 원소를 더한 값을 출력하시오.

# %% [markdown]
# *Additional Comment*
#
# 이 문제에서 정의한 '미지의 연산 (◎)' 은, 7월에 진행되는 '교육자료 세미나' 에서 "Convolution" 이라는 이름의 연산으로 다시 배우게 될 것이다.

# %% [markdown]
# **(9)** 위의 (8)까지 모든 소문항을 해결하였다면, 아래 코드를 실행해 2번 문제에 대한 채점을 진행해 볼 수 있다. 총 100개의 Test Case 에 대해, 채점이 진행된다.
#
# * 채점 도중 에러 (IndexError)가 발생하는 경우, Class 구현이 잘못된 경우입니다. Class 내의 변수 및 함수들을 수정한 후 다시 채점을 진행해 보시기 바랍니다.

# %%
from wk2_class_grading import grade
grade(operation)
